# %%
import tensorflow as tf
import keras as keras
import matplotlib.pyplot as plt
import os

import keras.utils as img

# %%
images_path = "C:\\Users\\fijal\Documents\Repository\BIAI\sorted_data\sorted_data"
class_names = os.listdir(images_path)
number_of_classes = len(class_names)
data_set = img.image_dataset_from_directory(images_path, class_names=class_names)
DATASET_SIZE = (len(data_set))
train_size = int(0.7 * DATASET_SIZE)
val_size = int(0.15 * DATASET_SIZE)
test_size = int(0.15 * DATASET_SIZE)

train_dataset = data_set.take(train_size)
test_dataset = data_set.skip(train_size)
val_dataset = test_dataset.skip(test_size)
test_dataset = test_dataset.take(test_size)
# Out:
# Found 19802 files belonging to 2 classes.

# %%
model3 = keras.Sequential(
    [
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(256, 256, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(2048, activation='relu'),
        tf.keras.layers.Dense(number_of_classes, activation="softmax")
    ]
)
opt=tf.keras.optimizers.Adam(learning_rate=0.0005)
model3.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history3 = model3.fit(train_dataset, validation_data=val_dataset, epochs=30)
# Out:
# Epoch 1/30
# 433/433 [==============================] - 73s 161ms/step - loss: 2.8760 - accuracy: 0.5278 - val_loss: 0.6877 - val_accuracy: 0.5306
# Epoch 2/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.6883 - accuracy: 0.5490 - val_loss: 0.6807 - val_accuracy: 0.5606
# Epoch 3/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.6798 - accuracy: 0.5707 - val_loss: 0.6596 - val_accuracy: 0.5959
# Epoch 4/30
# 433/433 [==============================] - 69s 160ms/step - loss: 0.6587 - accuracy: 0.6018 - val_loss: 0.6518 - val_accuracy: 0.6159
# Epoch 5/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.6426 - accuracy: 0.6266 - val_loss: 0.6304 - val_accuracy: 0.6469
# Epoch 6/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.6210 - accuracy: 0.6445 - val_loss: 0.6599 - val_accuracy: 0.6422
# Epoch 7/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.5879 - accuracy: 0.6824 - val_loss: 0.6010 - val_accuracy: 0.6712
# Epoch 8/30
# 433/433 [==============================] - 69s 160ms/step - loss: 0.5345 - accuracy: 0.7239 - val_loss: 0.5717 - val_accuracy: 0.7129
# Epoch 9/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.4742 - accuracy: 0.7649 - val_loss: 0.6054 - val_accuracy: 0.7072
# Epoch 10/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.4086 - accuracy: 0.8125 - val_loss: 0.5710 - val_accuracy: 0.7055
# Epoch 11/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.3451 - accuracy: 0.8461 - val_loss: 0.5806 - val_accuracy: 0.7072
# Epoch 12/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.2886 - accuracy: 0.8798 - val_loss: 0.6355 - val_accuracy: 0.7272
# Epoch 13/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.2290 - accuracy: 0.9094 - val_loss: 0.6954 - val_accuracy: 0.7375
# Epoch 14/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.1740 - accuracy: 0.9327 - val_loss: 0.7342 - val_accuracy: 0.7415
# Epoch 15/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.1825 - accuracy: 0.9369 - val_loss: 0.6956 - val_accuracy: 0.7478
# Epoch 16/30
# 433/433 [==============================] - 69s 158ms/step - loss: 0.1330 - accuracy: 0.9564 - val_loss: 0.7416 - val_accuracy: 0.7478
# Epoch 17/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.1027 - accuracy: 0.9670 - val_loss: 1.3117 - val_accuracy: 0.7378
# Epoch 18/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.1257 - accuracy: 0.9610 - val_loss: 0.9350 - val_accuracy: 0.7435
# Epoch 19/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.0879 - accuracy: 0.9714 - val_loss: 0.8830 - val_accuracy: 0.7452
# Epoch 20/30
# 433/433 [==============================] - 69s 158ms/step - loss: 0.0776 - accuracy: 0.9740 - val_loss: 0.9312 - val_accuracy: 0.7598
# Epoch 21/30
# 433/433 [==============================] - 69s 158ms/step - loss: 0.0884 - accuracy: 0.9724 - val_loss: 0.8745 - val_accuracy: 0.7482
# Epoch 22/30
# 433/433 [==============================] - 69s 158ms/step - loss: 0.0732 - accuracy: 0.9768 - val_loss: 0.7894 - val_accuracy: 0.7565
# Epoch 23/30
# 433/433 [==============================] - 69s 158ms/step - loss: 0.0540 - accuracy: 0.9835 - val_loss: 0.9314 - val_accuracy: 0.7602
# Epoch 24/30
# 433/433 [==============================] - 69s 158ms/step - loss: 0.0563 - accuracy: 0.9817 - val_loss: 0.9753 - val_accuracy: 0.7622
# Epoch 25/30
# 433/433 [==============================] - 69s 158ms/step - loss: 0.0546 - accuracy: 0.9837 - val_loss: 1.0920 - val_accuracy: 0.7468
# Epoch 26/30
# 433/433 [==============================] - 69s 158ms/step - loss: 0.0711 - accuracy: 0.9787 - val_loss: 1.0227 - val_accuracy: 0.7315
# Epoch 27/30
# 433/433 [==============================] - 68s 158ms/step - loss: 0.0553 - accuracy: 0.9831 - val_loss: 0.8389 - val_accuracy: 0.7595
# Epoch 28/30
# 433/433 [==============================] - 68s 158ms/step - loss: 0.0606 - accuracy: 0.9824 - val_loss: 1.0278 - val_accuracy: 0.7468
# Epoch 29/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.0436 - accuracy: 0.9880 - val_loss: 1.0185 - val_accuracy: 0.7518
# Epoch 30/30
# 433/433 [==============================] - 69s 159ms/step - loss: 0.0322 - accuracy: 0.9909 - val_loss: 1.0258 - val_accuracy: 0.7525

# %%
results3 = model3.evaluate(test_dataset)
print("test loss, test acc:", results3)
# Out:
# 92/92 [==============================] - 9s 40ms/step - loss: 0.7957 - accuracy: 0.7748
# test loss, test acc: [0.7957004308700562, 0.774796187877655]

# %%
plt.figure(figsize=(10, 10))

for images, labels in val_dataset.take(1):
    classifications = model3(images)
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        index = (classifications[i].numpy()).tolist().index(max(classifications[i].numpy()))
        plt.title("Pred: " + class_names[index] + " | Real: " + class_names[labels[i]])

# %%
# summarize history for accuracy
plt.plot(history3.history['accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.title('model3 accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('model3 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
model3.save('C:\\Users\\fijal\Documents\Repository\BIAI\Models_5_brands\Model3')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\fijal\Documents\Repository\BIAI\Models_2_brands\Model3\assets
# INFO:tensorflow:Assets written to: C:\Users\fijal\Documents\Repository\BIAI\Models_2_brands\Model3\assets
